# %%
import matplotlib
import yt  #Get yt here https://yt-project.org/
import numpy as np  #Currently yt will only work with numpy version 1.20.3

# %%
plot_num = 300
diag_num = 300
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

dplot = yt.load(plotname)
ddiag = yt.load(diagname)

print(dplot.field_list)
print(ddiag.field_list)
# Out:
# yt : [INFO     ] 2021-06-18 16:33:08,728 Parameters: current_time              = 2.34375
# yt : [INFO     ] 2021-06-18 16:33:08,728 Parameters: domain_dimensions         = [512 512   1]
# yt : [INFO     ] 2021-06-18 16:33:08,729 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-06-18 16:33:08,729 Parameters: domain_right_edge         = [20. 20.  1.]
# yt : [INFO     ] 2021-06-18 16:33:08,758 Parameters: current_time              = 2.34375
# yt : [INFO     ] 2021-06-18 16:33:08,759 Parameters: domain_dimensions         = [512 512   1]
# yt : [INFO     ] 2021-06-18 16:33:08,759 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-06-18 16:33:08,760 Parameters: domain_right_edge         = [20. 20.  1.]
# [('boxlib', 's')]
# [('boxlib', 'Edensity')]

# %%
var = 's'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids()
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'Edensity'
s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids()
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-06-18 16:33:22,157 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,157 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,158 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,158 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,159 Making a fixed resolution buffer of (('boxlib', 's')) 800 by 800
# yt : [WARNING  ] 2021-06-18 16:33:22,202 Plot image for field ('boxlib', 's') has both positive and negative/zero values. Min = -1.000000, Max = 1.000000.
# yt : [WARNING  ] 2021-06-18 16:33:22,202 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-06-18 16:33:22,353 Making a fixed resolution buffer of (('boxlib', 's')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-06-18 16:33:22,687 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,688 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,688 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,689 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 16:33:22,689 Making a fixed resolution buffer of (('boxlib', 'Edensity')) 800 by 800
# yt : [WARNING  ] 2021-06-18 16:33:22,735 Plot image for field ('boxlib', 'Edensity') has both positive and negative/zero values. Min = -4.000000, Max = 4.000000.
# yt : [WARNING  ] 2021-06-18 16:33:22,736 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-06-18 16:33:22,906 Making a fixed resolution buffer of (('boxlib', 'Edensity')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ##
