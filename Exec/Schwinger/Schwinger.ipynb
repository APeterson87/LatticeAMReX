# %%
import matplotlib
import yt  #Get yt here https://yt-project.org/
import numpy as np  #Currently yt will only work with numpy version 1.20.3
# Out:
# /home/ThirdEye87/.local/lib/python3.8/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /home/ThirdEye87/.config/yt/ytrc is deprecated in favor of /home/ThirdEye87/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg

# %%
plot_num = 1000
diag_num = 1000
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

dplot = yt.load(plotname)
ddiag = yt.load(diagname)

print(dplot.field_list)
print(ddiag.field_list)
# Out:
# yt : [INFO     ] 2021-06-18 15:22:23,471 Parameters: current_time              = 7.8125
# yt : [INFO     ] 2021-06-18 15:22:23,472 Parameters: domain_dimensions         = [512 512   1]
# yt : [INFO     ] 2021-06-18 15:22:23,472 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-06-18 15:22:23,473 Parameters: domain_right_edge         = [20. 20.  1.]
# yt : [INFO     ] 2021-06-18 15:22:23,505 Parameters: current_time              = 7.8125
# yt : [INFO     ] 2021-06-18 15:22:23,505 Parameters: domain_dimensions         = [512 512   1]
# yt : [INFO     ] 2021-06-18 15:22:23,506 Parameters: domain_left_edge          = [-20. -20.   0.]
# yt : [INFO     ] 2021-06-18 15:22:23,506 Parameters: domain_right_edge         = [20. 20.  1.]
# [('boxlib', 'U_0_Im'), ('boxlib', 'U_0_Re'), ('boxlib', 'U_1_Im'), ('boxlib', 'U_1_Re')]
# [('boxlib', 'AbsU_0_Re'), ('boxlib', 'AbsU_1_Re'), ('boxlib', 'ActionDensity')]

# %%
var = 'AbsU_0_Re'
s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'ActionDensity'
s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids()
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-06-18 15:22:43,247 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,247 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,248 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,248 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,249 Making a fixed resolution buffer of (('boxlib', 'AbsU_0_Re')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-06-18 15:22:43,975 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,976 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,977 xlim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,977 ylim = -20.000000 20.000000
# yt : [INFO     ] 2021-06-18 15:22:43,978 Making a fixed resolution buffer of (('boxlib', 'ActionDensity')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
