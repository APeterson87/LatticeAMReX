# %%
import matplotlib
import yt  #Get yt here https://yt-project.org/
import numpy as np  #Currently yt will only work with numpy version 1.20.3
# Out:
# /home/ThirdEye87/.local/lib/python3.8/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /home/ThirdEye87/.config/yt/ytrc is deprecated in favor of /home/ThirdEye87/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg

# %%
plot_num = 100
diag_num = 0
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

dplot = yt.load(plotname)
#ddiag = yt.load(diagname)

var = 'TopChargeDensity'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

plot_num = 0
diag_num = 0
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

dplot = yt.load(plotname)
#ddiag = yt.load(diagname)

var = 'TopChargeDensity'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-08-31 11:54:43,245 Parameters: current_time              = 100.0
# yt : [INFO     ] 2021-08-31 11:54:43,246 Parameters: domain_dimensions         = [32 32  1]
# yt : [INFO     ] 2021-08-31 11:54:43,246 Parameters: domain_left_edge          = [-16. -16.   0.]
# yt : [INFO     ] 2021-08-31 11:54:43,247 Parameters: domain_right_edge         = [16. 16.  1.]
# yt : [INFO     ] 2021-08-31 11:54:43,476 xlim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:43,476 ylim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:43,477 xlim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:43,477 ylim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:43,478 Making a fixed resolution buffer of (('boxlib', 'TopChargeDensity')) 800 by 800
# yt : [WARNING  ] 2021-08-31 11:54:43,501 Plot image for field ('boxlib', 'TopChargeDensity') has both positive and negative/zero values. Min = -0.460738, Max = 0.436683.
# yt : [WARNING  ] 2021-08-31 11:54:43,501 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-08-31 11:54:43,656 Making a fixed resolution buffer of (('boxlib', 'TopChargeDensity')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-08-31 11:54:43,970 Parameters: current_time              = 0.0
# yt : [INFO     ] 2021-08-31 11:54:43,970 Parameters: domain_dimensions         = [32 32  1]
# yt : [INFO     ] 2021-08-31 11:54:43,971 Parameters: domain_left_edge          = [-16. -16.   0.]
# yt : [INFO     ] 2021-08-31 11:54:43,971 Parameters: domain_right_edge         = [16. 16.  1.]
# yt : [INFO     ] 2021-08-31 11:54:44,184 xlim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:44,184 ylim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:44,185 xlim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:44,185 ylim = -16.000000 16.000000
# yt : [INFO     ] 2021-08-31 11:54:44,186 Making a fixed resolution buffer of (('boxlib', 'TopChargeDensity')) 800 by 800
# yt : [WARNING  ] 2021-08-31 11:54:44,204 Plot image for field ('boxlib', 'TopChargeDensity') has zero dynamic range. Min = Max = 0.000000.
# yt : [WARNING  ] 2021-08-31 11:54:44,205 Switching to linear colorbar scaling.
# yt : [INFO     ] 2021-08-31 11:54:44,306 Making a fixed resolution buffer of (('boxlib', 'TopChargeDensity')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
var = 'U_0_Real'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-07-16 08:38:30,499 xlim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,500 ylim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,500 xlim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,501 ylim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,502 Making a fixed resolution buffer of (('boxlib', 'U_0_Real')) 800 by 800
# yt : [WARNING  ] 2021-07-16 08:38:30,525 Plot image for field ('boxlib', 'U_0_Real') has both positive and negative/zero values. Min = -1.000000, Max = 0.999967.
# yt : [WARNING  ] 2021-07-16 08:38:30,525 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-16 08:38:30,661 Making a fixed resolution buffer of (('boxlib', 'U_0_Real')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-07-16 08:38:30,945 xlim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,945 ylim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,946 xlim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,946 ylim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:30,947 Making a fixed resolution buffer of (('boxlib', 'DDp_0_Real')) 800 by 800
# yt : [WARNING  ] 2021-07-16 08:38:30,966 Plot image for field ('boxlib', 'DDp_0_Real') has zero dynamic range. Min = Max = 0.000000.
# yt : [WARNING  ] 2021-07-16 08:38:30,966 Switching to linear colorbar scaling.
# yt : [INFO     ] 2021-07-16 08:38:31,064 Making a fixed resolution buffer of (('boxlib', 'DDp_0_Real')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-07-16 08:38:31,416 xlim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:31,416 ylim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:31,417 xlim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:31,417 ylim = -8.000000 8.000000
# yt : [INFO     ] 2021-07-16 08:38:31,418 Making a fixed resolution buffer of (('boxlib', 'U_0_Imaginary')) 800 by 800
# yt : [WARNING  ] 2021-07-16 08:38:31,441 Plot image for field ('boxlib', 'U_0_Imaginary') has both positive and negative/zero values. Min = -0.999966, Max = 0.999999.
# yt : [WARNING  ] 2021-07-16 08:38:31,442 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-16 08:38:31,577 Making a fixed resolution buffer of (('boxlib', 'U_0_Imaginary')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
var = 'Q_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-07-01 09:00:41,748 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,748 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,749 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,749 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,750 Making a fixed resolution buffer of (('boxlib', 'Q_0')) 800 by 800
# yt : [WARNING  ] 2021-07-01 09:00:41,774 Plot image for field ('boxlib', 'Q_0') has both positive and negative/zero values. Min = -3.379104, Max = 3.323238.
# yt : [WARNING  ] 2021-07-01 09:00:41,774 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-01 09:00:41,922 Making a fixed resolution buffer of (('boxlib', 'Q_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
var = 'Qcurrent_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-07-01 08:54:29,310 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,313 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,315 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,315 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,316 Making a fixed resolution buffer of (('boxlib', 'Qcurrent_0')) 800 by 800
# yt : [WARNING  ] 2021-07-01 08:54:29,344 Plot image for field ('boxlib', 'Qcurrent_0') has both positive and negative/zero values. Min = -3.158025, Max = 3.159372.
# yt : [WARNING  ] 2021-07-01 08:54:29,345 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-01 08:54:29,555 Making a fixed resolution buffer of (('boxlib', 'Qcurrent_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
