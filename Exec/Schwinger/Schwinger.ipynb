# %%
import matplotlib
import yt  #Get yt here https://yt-project.org/
import numpy as np  #Currently yt will only work with numpy version 1.20.3

# %%
plot_num = 5
plot_num += 1000000
plot_num_list = list(str(plot_num))
plot_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
dplot = yt.load(plotname)
print(dplot.field_list)

var = 'P_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
s.annotate_cell_edges()
s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'P_1'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
s.annotate_cell_edges()
s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'U_0_Real'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.75, 1.25)
#s.hide_colorbar()
#s.hide_axes()
s.annotate_cell_edges()
s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'U_0_Imaginary'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), -1, 1)
#s.hide_colorbar()
#s.hide_axes()
s.annotate_cell_edges()
s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'U_1_Real'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.75, 1.25)
#s.hide_colorbar()
#s.hide_axes()
s.annotate_cell_edges()
s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'U_1_Imaginary'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), -1, 1)
#s.hide_colorbar()
#s.hide_axes()
s.annotate_cell_edges()
s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2022-10-07 15:18:32,758 Parameters: current_time              = 5.0
# yt : [INFO     ] 2022-10-07 15:18:32,759 Parameters: domain_dimensions         = [32 32  1]
# yt : [INFO     ] 2022-10-07 15:18:32,759 Parameters: domain_left_edge          = [-16. -16.   0.]
# yt : [INFO     ] 2022-10-07 15:18:32,760 Parameters: domain_right_edge         = [16. 16.  1.]
# yt : [INFO     ] 2022-10-07 15:18:32,970 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:32,970 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:32,971 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:32,972 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:32,972 Making a fixed resolution buffer of (('boxlib', 'P_0')) 800 by 800
# yt : [WARNING  ] 2022-10-07 15:18:32,995 Plotting ('boxlib', 'P_0'): Both positive and negative values. Min = -11.358705137355866 dimensionless, Max = 9.611205349515105 dimensionless.
# yt : [WARNING  ] 2022-10-07 15:18:32,996 Switching to symlog colorbar scaling.
# [('boxlib', 'P_0'), ('boxlib', 'P_1'), ('boxlib', 'Phi_0_Imaginary'), ('boxlib', 'Phi_0_Real'), ('boxlib', 'Phi_1_Imaginary'), ('boxlib', 'Phi_1_Real'), ('boxlib', 'U_0_Imaginary'), ('boxlib', 'U_0_Real'), ('boxlib', 'U_1_Imaginary'), ('boxlib', 'U_1_Real')]
# yt : [INFO     ] 2022-10-07 15:18:33,300 Making a fixed resolution buffer of (('boxlib', 'P_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-10-07 15:18:33,723 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:33,723 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:33,724 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:33,724 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:33,725 Making a fixed resolution buffer of (('boxlib', 'P_1')) 800 by 800
# yt : [WARNING  ] 2022-10-07 15:18:33,747 Plotting ('boxlib', 'P_1'): Both positive and negative values. Min = -8.245954434878234 dimensionless, Max = 15.32685426969089 dimensionless.
# yt : [WARNING  ] 2022-10-07 15:18:33,747 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2022-10-07 15:18:34,052 Making a fixed resolution buffer of (('boxlib', 'P_1')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-10-07 15:18:34,439 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:34,439 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:34,440 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:34,440 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:34,441 Making a fixed resolution buffer of (('boxlib', 'U_0_Real')) 800 by 800
# yt : [WARNING  ] 2022-10-07 15:18:34,463 Plotting ('boxlib', 'U_0_Real'): Both positive and negative values. Min = -2.8106351223528248 dimensionless, Max = 7.000000000000945 dimensionless.
# yt : [WARNING  ] 2022-10-07 15:18:34,463 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2022-10-07 15:18:34,797 Making a fixed resolution buffer of (('boxlib', 'U_0_Real')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-10-07 15:18:35,188 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,188 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,189 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,189 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,190 Making a fixed resolution buffer of (('boxlib', 'U_0_Imaginary')) 800 by 800
# yt : [WARNING  ] 2022-10-07 15:18:35,212 Plotting ('boxlib', 'U_0_Imaginary'): Both positive and negative values. Min = -2.9587567510300086 dimensionless, Max = 3.506035955803281 dimensionless.
# yt : [WARNING  ] 2022-10-07 15:18:35,212 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2022-10-07 15:18:35,461 Making a fixed resolution buffer of (('boxlib', 'U_0_Imaginary')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-10-07 15:18:35,866 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,867 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,868 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,868 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:35,869 Making a fixed resolution buffer of (('boxlib', 'U_1_Real')) 800 by 800
# yt : [WARNING  ] 2022-10-07 15:18:35,890 Plotting ('boxlib', 'U_1_Real'): Both positive and negative values. Min = -1.994555753933921 dimensionless, Max = 7.000000000000945 dimensionless.
# yt : [WARNING  ] 2022-10-07 15:18:35,891 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2022-10-07 15:18:36,175 Making a fixed resolution buffer of (('boxlib', 'U_1_Real')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2022-10-07 15:18:36,593 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:36,594 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:36,594 xlim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:36,595 ylim = -16.000000 16.000000
# yt : [INFO     ] 2022-10-07 15:18:36,595 Making a fixed resolution buffer of (('boxlib', 'U_1_Imaginary')) 800 by 800
# yt : [WARNING  ] 2022-10-07 15:18:36,619 Plotting ('boxlib', 'U_1_Imaginary'): Both positive and negative values. Min = -3.6824174775844174 dimensionless, Max = 3.5225336571899293 dimensionless.
# yt : [WARNING  ] 2022-10-07 15:18:36,620 Switching to symlog colorbar scaling.
# yt : [INFO     ] 2022-10-07 15:18:36,836 Making a fixed resolution buffer of (('boxlib', 'U_1_Imaginary')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
var = 'P_0'
cg = dplot.covering_grid(left_edge=dplot.domain_left_edge, dims=dplot.domain_dimensions, level=0)
coords = cg.fcoords

xs = coords[:,0]
ys = coords[:,1]
zs = coords[:,2]

dx = np.max(xs[1:] - xs[:-1])
dy = np.max(ys[1:] - ys[:-1])
dz = np.max(zs[1:] - zs[:-1])

H = cg[var][:,:,:].d

# %%
H[18,18,0]
# Out:
# 0.0

# %%
var = 'Q_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# <ipython-input-12-7fe60060d058> in <module>
#       1 var = 'Q_0'
# ----> 2 s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
#       3 s.set_log(('boxlib', var), False)
#       4 s.set_xlabel('x - Axis')
#       5 s.set_ylabel('y - Axis')
#
# ~/.local/lib/python3.8/site-packages/yt/visualization/plot_window.py in SlicePlot(ds, normal, fields, axis, *args, **kwargs)
#    2482             del kwargs["north_vector"]
#    2483
# -> 2484         return AxisAlignedSlicePlot(ds, normal, fields, *args, **kwargs)
#    2485
#    2486
#
# ~/.local/lib/python3.8/site-packages/yt/visualization/plot_window.py in __init__(self, ds, axis, fields, center, width, axes_unit, origin, right_handed, fontsize, field_parameters, window_size, aspect, data_source, buff_size)
#    1610                 data_source=data_source,
#    1611             )
# -> 1612             slc.get_data(fields)
#    1613         validate_mesh_fields(slc, fields)
#    1614         PWViewerMPL.__init__(
#
# ~/.local/lib/python3.8/site-packages/yt/data_objects/selection_objects/data_selection_objects.py in get_data(self, fields)
#     133         nfields = []
#     134         apply_fields = defaultdict(list)
# --> 135         for field in self._determine_fields(fields):
#     136             # We need to create the field on the raw particle types
#     137             # for particles types (when the field is not directly
#
# ~/.local/lib/python3.8/site-packages/yt/data_objects/data_containers.py in _determine_fields(self, fields)
#    1450             ftype, fname = self._tupleize_field(field)
#    1451             # print(field, " : ",ftype, fname)
# -> 1452             finfo = self.ds._get_field_info(ftype, fname)
#    1453
#    1454             # really ugly check to ensure that this field really does exist somewhere,
#
# ~/.local/lib/python3.8/site-packages/yt/data_objects/static_output.py in _get_field_info(self, ftype, fname)
#     817
#     818     def _get_field_info(self, ftype, fname=None):
# --> 819         field_info, is_ambiguous = self._get_field_info_helper(ftype, fname)
#     820
#     821         if is_ambiguous:
#
# ~/.local/lib/python3.8/site-packages/yt/data_objects/static_output.py in _get_field_info_helper(self, ftype, fname)
#     895                     self._last_finfo = self.field_info[(ftype, fname)]
#     896                     return self._last_finfo, is_ambiguous
# --> 897         raise YTFieldNotFound(field=INPUT, ds=self)
#     898
#     899     def _setup_classes(self):
#
# YTFieldNotFound: Could not find field ('boxlib', 'Q_0') in plt0000000.
# Did you mean:
# 	('boxlib', 'P_0')
# 	('boxlib', 'P_1')

# %%
var = 'Qcurrent_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-07-01 08:54:29,310 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,313 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,315 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,315 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,316 Making a fixed resolution buffer of (('boxlib', 'Qcurrent_0')) 800 by 800
# yt : [WARNING  ] 2021-07-01 08:54:29,344 Plot image for field ('boxlib', 'Qcurrent_0') has both positive and negative/zero values. Min = -3.158025, Max = 3.159372.
# yt : [WARNING  ] 2021-07-01 08:54:29,345 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-01 08:54:29,555 Making a fixed resolution buffer of (('boxlib', 'Qcurrent_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
