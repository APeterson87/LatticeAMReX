# %%
import matplotlib
import yt  #Get yt here https://yt-project.org/
import numpy as np  #Currently yt will only work with numpy version 1.20.3

# %%
plot_num = 100000
diag_num = 100000
plot_num += 1000000
diag_num += 1000000
plot_num_list = list(str(plot_num))
diag_num_list = list(str(diag_num))
plot_num_list[0] = '0'
diag_num_list[0] = '0'
plotname = "plt"+"".join(plot_num_list)
diagname = "diag"+"".join(diag_num_list)

dplot = yt.load(plotname)
ddiag = yt.load(diagname)

print(dplot.field_list)
print(ddiag.field_list)
# Out:
# yt : [INFO     ] 2021-07-02 15:34:31,907 Parameters: current_time              = 100000.0
# yt : [INFO     ] 2021-07-02 15:34:31,907 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2021-07-02 15:34:31,908 Parameters: domain_left_edge          = [-32. -32.   0.]
# yt : [INFO     ] 2021-07-02 15:34:31,908 Parameters: domain_right_edge         = [32. 32.  1.]
# yt : [INFO     ] 2021-07-02 15:34:31,937 Parameters: current_time              = 100000.0
# yt : [INFO     ] 2021-07-02 15:34:31,938 Parameters: domain_dimensions         = [64 64  1]
# yt : [INFO     ] 2021-07-02 15:34:31,938 Parameters: domain_left_edge          = [-32. -32.   0.]
# yt : [INFO     ] 2021-07-02 15:34:31,939 Parameters: domain_right_edge         = [32. 32.  1.]
# [('boxlib', 'P_0'), ('boxlib', 'P_1'), ('boxlib', 'Pcurrent_0'), ('boxlib', 'Pcurrent_1'), ('boxlib', 'U_0_Imaginary'), ('boxlib', 'U_0_Real'), ('boxlib', 'U_1_Imaginary'), ('boxlib', 'U_1_Real'), ('boxlib', 'Ucurrent_0_Imaginary'), ('boxlib', 'Ucurrent_0_Real'), ('boxlib', 'Ucurrent_1_Imaginary'), ('boxlib', 'Ucurrent_1_Real')]
# [('boxlib', 'AbsU_0_Re'), ('boxlib', 'AbsU_1_Re'), ('boxlib', 'ActionDensity')]

# %%
var = 'Ucurrent_0_Real'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()

var = 'ActionDensity'
s = yt.SlicePlot(ddiag, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-07-02 15:34:38,353 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,353 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,354 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,355 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,356 Making a fixed resolution buffer of (('boxlib', 'Ucurrent_0_Real')) 800 by 800
# yt : [WARNING  ] 2021-07-02 15:34:38,379 Plot image for field ('boxlib', 'Ucurrent_0_Real') has both positive and negative/zero values. Min = -1.000000, Max = 1.000000.
# yt : [WARNING  ] 2021-07-02 15:34:38,380 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-02 15:34:38,582 Making a fixed resolution buffer of (('boxlib', 'Ucurrent_0_Real')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2021-07-02 15:34:38,862 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,863 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,864 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,864 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-02 15:34:38,865 Making a fixed resolution buffer of (('boxlib', 'ActionDensity')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
var = 'Q_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-07-01 09:00:41,748 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,748 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,749 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,749 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 09:00:41,750 Making a fixed resolution buffer of (('boxlib', 'Q_0')) 800 by 800
# yt : [WARNING  ] 2021-07-01 09:00:41,774 Plot image for field ('boxlib', 'Q_0') has both positive and negative/zero values. Min = -3.379104, Max = 3.323238.
# yt : [WARNING  ] 2021-07-01 09:00:41,774 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-01 09:00:41,922 Making a fixed resolution buffer of (('boxlib', 'Q_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
var = 'Qcurrent_0'
s = yt.SlicePlot(dplot, 'z', ('boxlib', var), origin='native', center = [0,0,0])
s.set_log(('boxlib', var), False)
s.set_xlabel('x - Axis')
s.set_ylabel('y - Axis')
#s.set_zlim(('boxlib', var), 0.075, 0.6)
#s.hide_colorbar()
#s.hide_axes()
#s.annotate_cell_edges()
#s.annotate_grids(min_level = 0, edgecolors='lightgray')
#s.set_cmap('alpha', 'RdBu_r')
s.zoom(1)
s.show()
# Out:
# yt : [INFO     ] 2021-07-01 08:54:29,310 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,313 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,315 xlim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,315 ylim = -32.000000 32.000000
# yt : [INFO     ] 2021-07-01 08:54:29,316 Making a fixed resolution buffer of (('boxlib', 'Qcurrent_0')) 800 by 800
# yt : [WARNING  ] 2021-07-01 08:54:29,344 Plot image for field ('boxlib', 'Qcurrent_0') has both positive and negative/zero values. Min = -3.158025, Max = 3.159372.
# yt : [WARNING  ] 2021-07-01 08:54:29,345 Log-scaling specified: switching to symlog colorbar scaling unless linear scaling is specified later
# yt : [INFO     ] 2021-07-01 08:54:29,555 Making a fixed resolution buffer of (('boxlib', 'Qcurrent_0')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
